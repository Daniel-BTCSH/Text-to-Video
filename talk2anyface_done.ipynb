# %%
#判断人脸
# !pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.9/dist-packages (from face_recognition) (19.24.0)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from face_recognition) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from face_recognition) (1.22.4)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.9/dist-packages (from face_recognition) (8.1.3)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=5b72606f4b5703ef3952da68a63f5f1916d05dc4d851c3684f061074cf43fb8c
#   Stored in directory: /root/.cache/pip/wheels/22/a8/60/4a2aeb763d63f50190f4c4e07069a22245347eeafdb3a67551
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face_recognition
# Successfully installed face-recognition-models-0.3.0 face_recognition-1.3.0

# %%
import torch
torch.version.cuda
# Out:
# '11.6'

# %%
#@title
# !pip install paddlepaddle-gpu==2.4.1.post116 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Collecting paddlepaddle-gpu==2.4.1.post116
#   Downloading https://paddle-wheel.bj.bcebos.com/2.4.1/linux/linux-gpu-cuda11.6-cudnn8.4.0-mkl-gcc8.2-avx/paddlepaddle_gpu-2.4.1.post116-cp39-cp39-linux_x86_64.whl (567.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.4/567.4 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from paddlepaddle-gpu==2.4.1.post116) (1.15.0)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: protobuf<=3.20.0,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from paddlepaddle-gpu==2.4.1.post116) (3.19.6)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.9/dist-packages (from paddlepaddle-gpu==2.4.1.post116) (1.22.4)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.9/dist-packages (from paddlepaddle-gpu==2.4.1.post116) (3.3.0)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.9/dist-packages (from paddlepaddle-gpu==2.4.1.post116) (2.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from paddlepaddle-gpu==2.4.1.post116) (8.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from paddlepaddle-gpu==2.4.1.post116) (4.4.2)
# Collecting paddle-bfloat==0.1.7
#   Downloading paddle_bfloat-0.1.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.1/383.1 KB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post116) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post116) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post116) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post116) (2.0.12)
# Installing collected packages: paddle-bfloat, astor, paddlepaddle-gpu
# Successfully installed astor-0.8.1 paddle-bfloat-0.1.7 paddlepaddle-gpu-2.4.1.post116

# %%
#聊天机器人
# !pip install --upgrade paddlenlp>=2.0.0rc -i https://pypi.org/simple
from paddlenlp import Taskflow
dialogue = Taskflow("dialogue")
dialogue(['你好呀'])
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# [2023-03-19 13:12:57,469] [    INFO] - Downloading model_state.pdparams from https://bj.bcebos.com/paddlenlp/taskflow/dialogue/plato-mini/model_state.pdparams
#   0%|          | 0.00/518M [00:00<?, ?B/s]
# [2023-03-19 13:14:05,831] [    INFO] - Downloading model_config.json from https://bj.bcebos.com/paddlenlp/taskflow/dialogue/plato-mini/model_config.json
#   0%|          | 0.00/518 [00:00<?, ?B/s]
# [2023-03-19 13:14:07,489] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/transformers/unified_transformer/plato-mini-vocab.txt and saved to /root/.paddlenlp/models/plato-mini
# [2023-03-19 13:14:08,489] [    INFO] - Downloading plato-mini-vocab.txt from https://bj.bcebos.com/paddlenlp/models/transformers/unified_transformer/plato-mini-vocab.txt
#   0%|          | 0.00/410k [00:00<?, ?B/s]
# [2023-03-19 13:14:15,636] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/transformers/unified_transformer/plato-mini-spm.model and saved to /root/.paddlenlp/models/plato-mini
# [2023-03-19 13:14:16,677] [    INFO] - Downloading plato-mini-spm.model from https://bj.bcebos.com/paddlenlp/models/transformers/unified_transformer/plato-mini-spm.model
#   0%|          | 0.00/711k [00:00<?, ?B/s]
# [2023-03-19 13:14:25,805] [    INFO] - tokenizer config file saved in /root/.paddlenlp/models/plato-mini/tokenizer_config.json
# [2023-03-19 13:14:25,807] [    INFO] - Special tokens file saved in /root/.paddlenlp/models/plato-mini/special_tokens_map.json
# [2023-03-19 13:14:25,811] [    INFO] - Model config UnifiedTransformerConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "mask_token_id": 30000,
#   "max_position_embeddings": 512,
#   "model_type": "unified_transformer",
#   "normalize_before": true,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 6,
#   "pad_token_id": 0,
#   "paddlenlp_version": null,
#   "role_type_size": null,
#   "type_vocab_size": 2,
#   "unk_token_id": 0,
#   "vocab_size": 30001
# }
#
# [2023-03-19 13:14:25,814] [    INFO] - Configuration saved in /root/.paddlenlp/models/plato-mini/config.json
# [2023-03-19 13:14:25,816] [    INFO] - Downloading plato-mini.pdparams from https://bj.bcebos.com/paddlenlp/models/transformers/unified_transformer/plato-mini.pdparams
#   0%|          | 0.00/518M [00:00<?, ?B/s]
# [2023-03-19 13:15:40,070] [    INFO] - All model checkpoint weights were used when initializing UnifiedTransformerLMHeadModel.
#
# [2023-03-19 13:15:40,071] [    INFO] - All the weights of UnifiedTransformerLMHeadModel were initialized from the model checkpoint at plato-mini.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UnifiedTransformerLMHeadModel for predictions without further training.
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.668 seconds.
# DEBUG:jieba:Loading model cost 0.668 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# [2023-03-19 13:15:40,750] [ WARNING] - Accessing `bos_token_id` through `model.bos_token_id` will be deprecated after v2.6.0. Instead, do `model.config.bos_token_id`
# [2023-03-19 13:15:40,751] [ WARNING] - Accessing `eos_token_id` through `model.eos_token_id` will be deprecated after v2.6.0. Instead, do `model.config.eos_token_id`
# [2023-03-19 13:15:40,752] [ WARNING] - Accessing `pad_token_id` through `model.pad_token_id` will be deprecated after v2.6.0. Instead, do `model.config.pad_token_id`
# [2023-03-19 13:15:40,753] [ WARNING] - Accessing `forced_bos_token_id` through `model.forced_bos_token_id` will be deprecated after v2.6.0. Instead, do `model.config.forced_bos_token_id`
# [2023-03-19 13:15:40,754] [ WARNING] - Accessing `forced_eos_token_id` through `model.forced_eos_token_id` will be deprecated after v2.6.0. Instead, do `model.config.forced_eos_token_id`
# [2023-03-19 13:15:40,755] [ WARNING] - Accessing `decoder_start_token_id` through `model.decoder_start_token_id` will be deprecated after v2.6.0. Instead, do `model.config.decoder_start_token_id`
# [2023-03-19 13:15:40,756] [ WARNING] - Accessing `no_repeat_ngram_size` through `model.no_repeat_ngram_size` will be deprecated after v2.6.0. Instead, do `model.config.no_repeat_ngram_size`
# ['你好']

# %%
# 语音
# !pip install --upgrade pytest-runner 
# !pip install --upgrade paddlespeech
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytest-runner
#   Downloading pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Installing collected packages: pytest-runner
# Successfully installed pytest-runner-6.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting paddlespeech
#   Downloading paddlespeech-1.4.1-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.7 MB/s eta 0:00:00
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 7.2 MB/s eta 0:00:00
# Collecting jsonlines
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting pypinyin-dict
#   Downloading pypinyin_dict-0.5.0-py2.py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 66.0 MB/s eta 0:00:00
# Collecting sacrebleu
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 8.8 MB/s eta 0:00:00
# Collecting timer
#   Downloading timer-0.2.2-py3-none-any.whl (7.8 kB)
# Collecting nara-wpe
#   Downloading nara_wpe-0.0.9-py3-none-any.whl (33 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (6.0.2)
# Collecting textgrid
#   Downloading TextGrid-1.5-py3-none-any.whl (10.0 kB)
# Collecting webrtcvad
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 KB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting resampy
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.9 MB/s eta 0:00:00
# Collecting g2p-en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 102.8 MB/s eta 0:00:00
# Requirement already satisfied: editdistance in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (0.5.3)
# Collecting onnxruntime>=1.11.0
#   Downloading onnxruntime-1.14.1-cp39-cp39-manylinux_2_27_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 110.7 MB/s eta 0:00:00
# Collecting paddleslim>=2.3.4
#   Downloading paddleslim-2.4.1-py3-none-any.whl (411 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.8/411.8 KB 40.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (2.8.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (3.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (6.0)
# Collecting zhon
#   Downloading zhon-1.1.5.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.8/99.8 KB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting opencc-python-reimplemented
#   Downloading opencc_python_reimplemented-0.1.7-py2.py3-none-any.whl (481 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.8/481.8 KB 26.2 MB/s eta 0:00:00
# Collecting librosa==0.8.1
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.8/203.8 KB 22.5 MB/s eta 0:00:00
# Collecting pypinyin<=0.44.0
#   Downloading pypinyin-0.44.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.8 MB/s eta 0:00:00
# Collecting typeguard==2.13.3
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting hyperpyyaml
#   Downloading HyperPyYAML-1.1.0-py3-none-any.whl (15 kB)
# Collecting ToJyutping
#   Downloading ToJyutping-0.2.3-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 74.6 MB/s eta 0:00:00
# Collecting g2pM
#   Downloading g2pM-0.1.2.5-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 77.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (1.4.4)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (3.6.0)
# Collecting opencc
#   Downloading OpenCC-1.1.6-cp39-cp39-manylinux1_x86_64.whl (778 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.3/778.3 KB 56.3 MB/s eta 0:00:00
# Collecting pattern-singleton
#   Downloading pattern_singleton-1.2.0.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (3.8.0)
# Collecting paddleaudio>=1.1.0
#   Downloading paddleaudio-1.1.0-cp39-cp39-manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 78.8 MB/s eta 0:00:00
# Collecting praatio<=5.1.1,>=5.0.0
#   Downloading praatio-5.1.1-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 9.9 MB/s eta 0:00:00
# Collecting paddlespeech-feat
#   Downloading paddlespeech_feat-0.1.0-py3-none-any.whl (12 kB)
# Collecting yacs~=0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: paddlenlp>=2.4.8 in /usr/local/lib/python3.9/dist-packages (from paddlespeech) (2.5.2)
# Collecting websockets
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 13.0 MB/s eta 0:00:00
# Collecting ppdiffusers>=0.9.0
#   Downloading ppdiffusers-0.11.1-py3-none-any.whl (639 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 639.2/639.2 KB 54.3 MB/s eta 0:00:00
# Collecting pyworld>=0.2.12
#   Downloading pyworld-0.3.2.tar.gz (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 KB 27.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (4.4.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (0.56.4)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (1.1.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (1.2.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (23.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (3.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (1.22.4)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (1.7.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->paddlespeech) (1.10.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.9/dist-packages (from onnxruntime>=1.11.0->paddlespeech) (3.19.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime>=1.11.0->paddlespeech) (1.11.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.9/dist-packages (from onnxruntime>=1.11.0->paddlespeech) (23.3.3)
# Collecting pathos
#   Downloading pathos-0.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 KB 216.6 kB/s eta 0:00:00
# Collecting kaldiio
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pybind11
#   Downloading pybind11-2.10.4-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 KB 17.2 MB/s eta 0:00:00
# Collecting parameterized
#   Downloading parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: Flask-Babel<3.0.0 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (2.0.0)
# Requirement already satisfied: dill<0.3.5 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.3.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (4.65.0)
# Requirement already satisfied: visualdl in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (2.4.2)
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.42.1)
# Requirement already satisfied: paddlefsl in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (1.1.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (13.3.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (6.7.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.1.97)
# Requirement already satisfied: paddle2onnx in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (1.0.6)
# Requirement already satisfied: multiprocess<=0.70.12.2 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.70.12.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (2.10.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.95.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.7.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.21.1)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (1.2.2)
# Requirement already satisfied: huggingface-hub>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.4.8->paddlespeech) (0.13.2)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.9/dist-packages (from paddleslim>=2.3.4->paddlespeech) (23.2.1)
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 51.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from paddleslim>=2.3.4->paddlespeech) (8.4.0)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from ppdiffusers>=0.9.0->paddlespeech) (2022.10.31)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from praatio<=5.1.1,>=5.0.0->paddlespeech) (4.5.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from pyworld>=0.2.12->paddlespeech) (0.29.33)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 KB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.9/dist-packages (from g2p-en->paddlespeech) (3.8.1)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from inflect->paddlespeech) (1.10.6)
# Collecting ruamel.yaml>=0.17.8
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from jsonlines->paddlespeech) (22.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->paddlespeech) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->paddlespeech) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->paddlespeech) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->paddlespeech) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->paddlespeech) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->paddlespeech) (1.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil->paddlespeech) (1.15.0)
# Collecting bottleneck
#   Downloading Bottleneck-1.3.7-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (353 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.1/353.1 KB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nara-wpe->paddlespeech) (8.1.3)
# Collecting mock
#   Downloading mock-5.0.1-py3-none-any.whl (30 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->paddlespeech) (2022.7.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prettytable->paddlespeech) (0.2.6)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.9/dist-packages (from sacrebleu->paddlespeech) (0.8.10)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from sacrebleu->paddlespeech) (4.9.2)
# Collecting pygtrie
#   Downloading pygtrie-2.5.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (3.8.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (3.2.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (9.0.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (0.18.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (2023.3.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (2.27.1)
# Requirement already satisfied: Flask in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3.0.0->paddlenlp>=2.4.8->paddlespeech) (2.2.3)
# Requirement already satisfied: Jinja2>=2.5 in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3.0.0->paddlenlp>=2.4.8->paddlespeech) (3.1.2)
# Requirement already satisfied: Babel>=2.3 in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3.0.0->paddlenlp>=2.4.8->paddlespeech) (2.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.11.1->paddlenlp>=2.4.8->paddlespeech) (3.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->paddlespeech) (3.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.43.0->librosa==0.8.1->paddlespeech) (63.4.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.43.0->librosa==0.8.1->paddlespeech) (0.39.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.9/dist-packages (from pooch>=1.0->librosa==0.8.1->paddlespeech) (3.1.1)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.4/519.4 KB 47.0 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.1->paddlespeech) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.9/dist-packages (from soundfile>=0.10.2->librosa==0.8.1->paddlespeech) (1.15.1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /usr/local/lib/python3.9/dist-packages (from fastapi->paddlenlp>=2.4.8->paddlespeech) (0.26.1)
# Collecting pathos
#   Downloading pathos-0.2.9-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 KB 9.3 MB/s eta 0:00:00
#   Downloading pathos-0.2.8-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 KB 9.8 MB/s eta 0:00:00
# Collecting ppft>=1.6.6.4
#   Downloading ppft-1.7.6.6-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 6.3 MB/s eta 0:00:00
# Collecting pox>=0.3.0
#   Downloading pox-0.3.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->paddlenlp>=2.4.8->paddlespeech) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->paddlenlp>=2.4.8->paddlespeech) (2.14.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime>=1.11.0->paddlespeech) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/dist-packages (from uvicorn->paddlenlp>=2.4.8->paddlespeech) (0.14.0)
# Requirement already satisfied: bce-python-sdk in /usr/local/lib/python3.9/dist-packages (from visualdl->paddlenlp>=2.4.8->paddlespeech) (0.8.79)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.8.1->paddlespeech) (2.21)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask->Flask-Babel<3.0.0->paddlenlp>=2.4.8->paddlespeech) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask->Flask-Babel<3.0.0->paddlenlp>=2.4.8->paddlespeech) (2.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask->Flask-Babel<3.0.0->paddlenlp>=2.4.8->paddlespeech) (6.0.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (6.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.5->Flask-Babel<3.0.0->paddlenlp>=2.4.8->paddlespeech) (2.1.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->paddlenlp>=2.4.8->paddlespeech) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.0.0->paddlenlp>=2.4.8->paddlespeech) (2022.12.7)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from starlette<0.27.0,>=0.26.1->fastapi->paddlenlp>=2.4.8->paddlespeech) (3.6.2)
# Requirement already satisfied: pycryptodome>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from bce-python-sdk->visualdl->paddlenlp>=2.4.8->paddlespeech) (3.17)
# Requirement already satisfied: future>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from bce-python-sdk->visualdl->paddlenlp>=2.4.8->paddlespeech) (0.18.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi->paddlenlp>=2.4.8->paddlespeech) (1.3.0)
# Building wheels for collected packages: pyworld, pattern-singleton, webrtcvad, zhon, distance, kaldiio
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.2-cp39-cp39-linux_x86_64.whl size=895526 sha256=650d4573b4c25ac50923184eb3cc7d060501be55b955830583a2fd7b3aa00e14
#   Stored in directory: /root/.cache/pip/wheels/c5/91/01/58aa68f1f055ce534049e668292b710500100da0262079b8f5
#   Building wheel for pattern-singleton (setup.py) ... done
#   Created wheel for pattern-singleton: filename=pattern_singleton-1.2.0-py2.py3-none-any.whl size=4223 sha256=abf3ae052e2503c1f088101065f2be32919ed2c749b3ae957e048dc294b3cdde
#   Stored in directory: /root/.cache/pip/wheels/aa/29/cf/756cdb6d34dcb12ddce24916f21f318c3da9d46539a2eb4972
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp39-cp39-linux_x86_64.whl size=80909 sha256=8f60154a27c02f2dca84efc733140b3a9a4954b0b08120804e5c0f75e6e51c25
#   Stored in directory: /root/.cache/pip/wheels/1f/fe/28/e8f0d5847ae2642b49fa974db1cea44d59ab59d0251c12f17b
#   Building wheel for zhon (setup.py) ... done
#   Created wheel for zhon: filename=zhon-1.1.5-py3-none-any.whl size=84318 sha256=b6fa2ee6d181b69440415a6bef010bbff5225058d8b67033efad51172816c016
#   Stored in directory: /root/.cache/pip/wheels/a3/4d/f7/33026ca375a2fbdbc04f9522ac48e3f3119e6f55d4a8f38fb6
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16275 sha256=f004312282ae4de2da38f94ea1c144af597e9b2734db599a01e191c8865df51b
#   Stored in directory: /root/.cache/pip/wheels/fb/b3/aa/04241cced6d1722b132273b1d6aafba317887ec004f48b853a
#   Building wheel for kaldiio (setup.py) ... done
#   Created wheel for kaldiio: filename=kaldiio-2.17.2-py3-none-any.whl size=24472 sha256=49363cb0a9c945aac9222ebedd931ba7baa58c30d8af382d2b71cad817fcd422
#   Stored in directory: /root/.cache/pip/wheels/5d/8b/4e/17aac05e86a04db23f508115dc5aa24a6077fa5357eaee0d78
# Successfully built pyworld pattern-singleton webrtcvad zhon distance kaldiio
# Installing collected packages: zhon, webrtcvad, timer, textgrid, swig, pygtrie, parameterized, opencc-python-reimplemented, opencc, distance, braceexpand, yacs, websockets, typeguard, ToJyutping, ruamel.yaml.clib, pyworld, pypinyin, pybind11, praatio, ppft, pox, portalocker, pattern-singleton, mock, loguru, kaldiio, jsonlines, humanfriendly, g2pM, ftfy, bottleneck, sacrebleu, ruamel.yaml, resampy, pypinyin-dict, pathos, paddlespeech-feat, coloredlogs, paddleslim, onnxruntime, nara-wpe, librosa, hyperpyyaml, g2p-en, paddleaudio, ppdiffusers, paddlespeech
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.0
#     Uninstalling librosa-0.10.0:
#       Successfully uninstalled librosa-0.10.0
# Successfully installed ToJyutping-0.2.3 bottleneck-1.3.7 braceexpand-0.1.7 coloredlogs-15.0.1 distance-0.1.3 ftfy-6.1.1 g2p-en-2.1.0 g2pM-0.1.2.5 humanfriendly-10.0 hyperpyyaml-1.1.0 jsonlines-3.1.0 kaldiio-2.17.2 librosa-0.8.1 loguru-0.6.0 mock-5.0.1 nara-wpe-0.0.9 onnxruntime-1.14.1 opencc-1.1.6 opencc-python-reimplemented-0.1.7 paddleaudio-1.1.0 paddleslim-2.4.1 paddlespeech-1.4.1 paddlespeech-feat-0.1.0 parameterized-0.8.1 pathos-0.2.8 pattern-singleton-1.2.0 portalocker-2.7.0 pox-0.3.2 ppdiffusers-0.11.1 ppft-1.7.6.6 praatio-5.1.1 pybind11-2.10.4 pygtrie-2.5.0 pypinyin-0.44.0 pypinyin-dict-0.5.0 pyworld-0.3.2 resampy-0.4.2 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7 sacrebleu-2.3.1 swig-4.1.1 textgrid-1.5 timer-0.2.2 typeguard-2.13.3 webrtcvad-2.0.10 websockets-10.4 yacs-0.1.8 zhon-1.1.5

# %%
import base64
import librosa
import soundfile as sf

def resample_rate(path,new_sample_rate = 16000):
    signal, sr = librosa.load(path, sr=None)
    wavfile = path.split('/')[-1]
    wavfile = wavfile.split('.')[0]
    file_name = wavfile + '_new.wav'
    new_signal = librosa.resample(signal, sr, new_sample_rate) # 
    #librosa.output.write_wav(file_name, new_signal , new_sample_rate) 
    sf.write(file_name, new_signal, new_sample_rate, subtype='PCM_24')
    print(f'{file_name} has download.')
    return file_name

# %%
# 测试语音
from paddlespeech.cli.asr.infer import ASRExecutor
from paddlespeech.cli.tts.infer import TTSExecutor

asr = ASRExecutor()
tts = TTSExecutor()

out_file =tts('你好呀，我是语音测试')
print('tts',out_file)

audio_file=resample_rate(out_file)
result = asr(audio_file=audio_file)
print('asr',result)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# 100%|██████████| 477172/477172 [01:06<00:00, 7193.45it/s]
# 100%|██████████| 893777/893777 [01:30<00:00, 9852.23it/s]
# 100%|██████████| 575056/575056 [01:04<00:00, 8856.16it/s]
# [2023-03-19 13:21:48,251] [    INFO] - Downloading https://bj.bcebos.com/paddle-hapi/models/bert/bert-base-chinese-vocab.txt and saved to /root/.paddlenlp/models/bert-base-chinese
# [2023-03-19 13:21:49,792] [    INFO] - Downloading bert-base-chinese-vocab.txt from https://bj.bcebos.com/paddle-hapi/models/bert/bert-base-chinese-vocab.txt
#   0%|          | 0.00/107k [00:00<?, ?B/s]
# [2023-03-19 13:21:51,832] [    INFO] - tokenizer config file saved in /root/.paddlenlp/models/bert-base-chinese/tokenizer_config.json
# [2023-03-19 13:21:51,834] [    INFO] - Special tokens file saved in /root/.paddlenlp/models/bert-base-chinese/special_tokens_map.json
# tts /content/output.wav
# output_new.wav has download.
# 100%|██████████| 487739/487739 [01:07<00:00, 7184.68it/s]
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting paddlespeech_ctcdecoders
#   Downloading paddlespeech_ctcdecoders-0.2.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (16.9 MB)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Installing collected packages: paddlespeech_ctcdecoders
# Successfully installed paddlespeech_ctcdecoders-0.2.1
# 2023-03-19 13:23:25.442 | INFO     | paddlespeech.s2t.modules.embedding:__init__:150 - max len: 5000
# asr 你好呀我是语音测试

# %%
# 文生图
# !pip install --upgrade ppdiffusers
from ppdiffusers import StableDiffusionPipeline
sd = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
text='girl'
prompt = "a symmetrical portrait of "+text+". intricate. lifelike. soft light. sony a 7 r iv 5 5 mm. cinematic post - processing "
images = sd(prompt, guidance_scale=7.5,
             num_inference_steps=20,
             height=416, width=416).images

image=images[0]
image.save("test.png")
print(image)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ppdiffusers in /usr/local/lib/python3.9/dist-packages (0.11.1)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.9/dist-packages (from ppdiffusers) (6.1.1)
# Requirement already satisfied: paddlenlp>=2.5.0 in /usr/local/lib/python3.9/dist-packages (from ppdiffusers) (2.5.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from ppdiffusers) (2022.10.31)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from ppdiffusers) (8.4.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (6.7.0)
# Requirement already satisfied: visualdl in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (2.4.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.7.0)
# Requirement already satisfied: paddlefsl in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (1.1.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.4.6)
# Requirement already satisfied: multiprocess<=0.70.12.2 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.70.12.2)
# Requirement already satisfied: dill<0.3.5 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.3.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.1.97)
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.42.1)
# Requirement already satisfied: huggingface-hub>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.13.2)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (2.10.1)
# Requirement already satisfied: paddle2onnx in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (1.0.6)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.95.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (13.3.2)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (1.2.2)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (0.21.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (4.65.0)
# Requirement already satisfied: Flask-Babel<3.0.0 in /usr/local/lib/python3.9/dist-packages (from paddlenlp>=2.5.0->ppdiffusers) (2.0.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->ppdiffusers) (0.2.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (1.22.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (3.8.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (3.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (1.4.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (0.18.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (23.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (2023.3.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (2.27.1)
# Requirement already satisfied: Babel>=2.3 in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (2.12.1)
# Requirement already satisfied: Jinja2>=2.5 in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (3.1.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (2022.7.1)
# Requirement already satisfied: Flask in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (2.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.11.1->paddlenlp>=2.5.0->ppdiffusers) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.11.1->paddlenlp>=2.5.0->ppdiffusers) (4.5.0)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /usr/local/lib/python3.9/dist-packages (from fastapi->paddlenlp>=2.5.0->ppdiffusers) (0.26.1)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.9/dist-packages (from fastapi->paddlenlp>=2.5.0->ppdiffusers) (1.10.6)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->paddlenlp>=2.5.0->ppdiffusers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->paddlenlp>=2.5.0->ppdiffusers) (2.14.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from seqeval->paddlenlp>=2.5.0->ppdiffusers) (1.2.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer->paddlenlp>=2.5.0->ppdiffusers) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/dist-packages (from uvicorn->paddlenlp>=2.5.0->ppdiffusers) (0.14.0)
# Requirement already satisfied: protobuf>=3.11.0 in /usr/local/lib/python3.9/dist-packages (from visualdl->paddlenlp>=2.5.0->ppdiffusers) (3.19.6)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from visualdl->paddlenlp>=2.5.0->ppdiffusers) (1.15.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from visualdl->paddlenlp>=2.5.0->ppdiffusers) (3.7.1)
# Requirement already satisfied: bce-python-sdk in /usr/local/lib/python3.9/dist-packages (from visualdl->paddlenlp>=2.5.0->ppdiffusers) (0.8.79)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask->Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (2.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask->Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (6.0.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask->Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (2.2.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (1.3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.5->Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (2.1.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->paddlenlp>=2.5.0->ppdiffusers) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.0.0->paddlenlp>=2.5.0->ppdiffusers) (3.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->paddlenlp>=2.5.0->ppdiffusers) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->paddlenlp>=2.5.0->ppdiffusers) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->paddlenlp>=2.5.0->ppdiffusers) (1.1.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from starlette<0.27.0,>=0.26.1->fastapi->paddlenlp>=2.5.0->ppdiffusers) (3.6.2)
# Requirement already satisfied: pycryptodome>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from bce-python-sdk->visualdl->paddlenlp>=2.5.0->ppdiffusers) (3.17)
# Requirement already satisfied: future>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from bce-python-sdk->visualdl->paddlenlp>=2.5.0->ppdiffusers) (0.18.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->visualdl->paddlenlp>=2.5.0->ppdiffusers) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->visualdl->paddlenlp>=2.5.0->ppdiffusers) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->visualdl->paddlenlp>=2.5.0->ppdiffusers) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->visualdl->paddlenlp>=2.5.0->ppdiffusers) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->visualdl->paddlenlp>=2.5.0->ppdiffusers) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->visualdl->paddlenlp>=2.5.0->ppdiffusers) (4.39.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->visualdl->paddlenlp>=2.5.0->ppdiffusers) (1.0.7)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi->paddlenlp>=2.5.0->ppdiffusers) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->Flask->Flask-Babel<3.0.0->paddlenlp>=2.5.0->ppdiffusers) (3.15.0)
# [2023-03-19 13:23:45,357] [    INFO] - Downloading model_index.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/model_index.json
#   0%|          | 0.00/601 [00:00<?, ?B/s]
# [2023-03-19 13:23:47,866] [    INFO] - Downloading scheduler_config.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/scheduler/scheduler_config.json
#   0%|          | 0.00/342 [00:00<?, ?B/s]
# [2023-03-19 13:23:48,926] [    INFO] - Downloading preprocessor_config.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json
#   0%|          | 0.00/342 [00:00<?, ?B/s]
# [2023-03-19 13:23:50,026] [    INFO] - loading configuration file https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json from cache at /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json
# [2023-03-19 13:23:50,028] [    INFO] - size should be a dictionary on of the following set of keys: ({'height', 'width'}, {'shortest_edge'}, {'shortest_edge', 'longest_edge'}), got 224. Converted to {'shortest_edge': 224}.
# [2023-03-19 13:23:50,029] [    INFO] - crop_size should be a dictionary on of the following set of keys: ({'height', 'width'}, {'shortest_edge'}, {'shortest_edge', 'longest_edge'}), got 224. Converted to {'height': 224, 'width': 224}.
# [2023-03-19 13:23:50,032] [    INFO] - Image processor CLIPFeatureExtractor {
#   "crop_size": {
#     "height": 224,
#     "width": 224
#   },
#   "do_center_crop": true,
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "feature_extractor_type": "CLIPFeatureExtractor",
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "CLIPFeatureExtractor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "shortest_edge": 224
#   }
# }
#
# [2023-03-19 13:23:50,034] [    INFO] - Downloading model_state.pdparams from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/unet/model_state.pdparams
#   0%|          | 0.00/3.20G [00:00<?, ?B/s]
# [2023-03-19 13:28:45,963] [    INFO] - Downloading config.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/unet/config.json
#   0%|          | 0.00/807 [00:00<?, ?B/s]
# [2023-03-19 13:28:54,248] [    INFO] - Downloading model_state.pdparams from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/vae/model_state.pdparams
#   0%|          | 0.00/319M [00:00<?, ?B/s]
# [2023-03-19 13:29:46,544] [    INFO] - Downloading config.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/vae/config.json
#   0%|          | 0.00/610 [00:00<?, ?B/s]
# [2023-03-19 13:29:49,656] [    INFO] - Downloading config.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/safety_checker/config.json
#   0%|          | 0.00/553 [00:00<?, ?B/s]
# [2023-03-19 13:29:50,735] [    INFO] - loading configuration file /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/safety_checker/config.json
# [2023-03-19 13:29:50,738] [    INFO] - Model config CLIPVisionConfig {
#   "architectures": [
#     "StableDiffusionSafetyChecker"
#   ],
#   "attention_dropout": 0.0,
#   "dropout": 0.0,
#   "hidden_act": "quick_gelu",
#   "hidden_size": 1024,
#   "image_size": 224,
#   "initializer_factor": 1.0,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "model_type": "clip_vision_model",
#   "num_attention_heads": 16,
#   "num_channels": 3,
#   "num_hidden_layers": 24,
#   "paddlenlp_version": null,
#   "patch_size": 14,
#   "projection_dim": 768,
#   "return_dict": true
# }
#
# [2023-03-19 13:29:51,750] [    INFO] - Downloading model_state.pdparams from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/safety_checker/model_state.pdparams
#   0%|          | 0.00/1.13G [00:00<?, ?B/s]
# [2023-03-19 13:32:16,153] [    INFO] - All model checkpoint weights were used when initializing StableDiffusionSafetyChecker.
#
# [2023-03-19 13:32:16,154] [    INFO] - All the weights of StableDiffusionSafetyChecker were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5/safety_checker.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use StableDiffusionSafetyChecker for predictions without further training.
# [2023-03-19 13:32:17,666] [    INFO] - Downloading config.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/text_encoder/config.json
#   0%|          | 0.00/592 [00:00<?, ?B/s]
# [2023-03-19 13:32:18,693] [    INFO] - loading configuration file /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/text_encoder/config.json
# [2023-03-19 13:32:18,696] [    INFO] - Model config CLIPTextConfig {
#   "_name_or_path": "openai/clip-vit-large-patch14",
#   "architectures": [
#     "CLIPTextModel"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "dropout": 0.0,
#   "eos_token_id": 2,
#   "hidden_act": "quick_gelu",
#   "hidden_size": 768,
#   "initializer_factor": 1.0,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 77,
#   "model_type": "clip_text_model",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "paddlenlp_version": null,
#   "projection_dim": 512,
#   "return_dict": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.21.0.dev0",
#   "vocab_size": 49408
# }
#
# [2023-03-19 13:32:19,692] [    INFO] - Downloading model_state.pdparams from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/text_encoder/model_state.pdparams
#   0%|          | 0.00/469M [00:00<?, ?B/s]
# [2023-03-19 13:33:19,846] [    INFO] - All model checkpoint weights were used when initializing CLIPTextModel.
#
# [2023-03-19 13:33:19,848] [    INFO] - All the weights of CLIPTextModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5/text_encoder.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use CLIPTextModel for predictions without further training.
# [2023-03-19 13:33:19,852] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/vocab.json and saved to /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer
# [2023-03-19 13:33:21,322] [    INFO] - Downloading vocab.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/vocab.json
#   0%|          | 0.00/842k [00:00<?, ?B/s]
# [2023-03-19 13:33:34,782] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/merges.txt and saved to /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer
# [2023-03-19 13:33:35,820] [    INFO] - Downloading merges.txt from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/merges.txt
#   0%|          | 0.00/512k [00:00<?, ?B/s]
# [2023-03-19 13:33:44,528] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/added_tokens.json and saved to /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer
# [2023-03-19 13:33:45,541] [    INFO] - Downloading added_tokens.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/added_tokens.json
#   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# [2023-03-19 13:33:46,607] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/special_tokens_map.json and saved to /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer
# [2023-03-19 13:33:47,634] [    INFO] - Downloading special_tokens_map.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/special_tokens_map.json
#   0%|          | 0.00/478 [00:00<?, ?B/s]
# [2023-03-19 13:33:48,792] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/tokenizer_config.json and saved to /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer
# [2023-03-19 13:33:49,804] [    INFO] - Downloading tokenizer_config.json from https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/tokenizer/tokenizer_config.json
#   0%|          | 0.00/312 [00:00<?, ?B/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F066B74DE80>

# %%
# 唇形
# !pip install --upgrade ppgan
from ppgan.apps.wav2lip_predictor import Wav2LipPredictor

wav2lip_predictor = Wav2LipPredictor(face_det_batch_size = 2,wav2lip_batch_size = 16,face_enhancement = True)
wav2lip_predictor.run("test.png", 'output.wav', 'res.mp4')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ppgan in /usr/local/lib/python3.9/dist-packages (2.1.0)
# Requirement already satisfied: scikit-image>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from ppgan) (0.19.3)
# Requirement already satisfied: numba==0.53.1 in /usr/local/lib/python3.9/dist-packages (from ppgan) (0.53.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.9/dist-packages (from ppgan) (5.5.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.9/dist-packages (from ppgan) (6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from ppgan) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from ppgan) (4.65.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.9/dist-packages (from ppgan) (2.5.0)
# Requirement already satisfied: librosa==0.8.1 in /usr/local/lib/python3.9/dist-packages (from ppgan) (0.8.1)
# Requirement already satisfied: imageio==2.9.0 in /usr/local/lib/python3.9/dist-packages (from ppgan) (2.9.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.9/dist-packages (from ppgan) (0.4.8)
# Requirement already satisfied: easydict in /usr/local/lib/python3.9/dist-packages (from ppgan) (1.10)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from ppgan) (1.10.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from ppgan) (4.6.0.66)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from imageio==2.9.0->ppgan) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from imageio==2.9.0->ppgan) (1.22.4)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (3.0.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (1.2.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (23.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (1.1.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (1.7.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (0.4.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (4.4.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.9/dist-packages (from librosa==0.8.1->ppgan) (0.12.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba==0.53.1->ppgan) (63.4.3)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /usr/local/lib/python3.9/dist-packages (from numba==0.53.1->ppgan) (0.36.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.0->ppgan) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.0->ppgan) (2023.3.15)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.0->ppgan) (3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->ppgan) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->ppgan) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->ppgan) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->ppgan) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->ppgan) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->ppgan) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->ppgan) (1.4.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch->ppgan) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->ppgan) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.9/dist-packages (from pooch>=1.0->librosa==0.8.1->ppgan) (3.1.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from pooch>=1.0->librosa==0.8.1->ppgan) (2.27.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.1->ppgan) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.9/dist-packages (from soundfile>=0.10.2->librosa==0.8.1->ppgan) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.8.1->ppgan) (2.21)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1->ppgan) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1->ppgan) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1->ppgan) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1->ppgan) (1.26.15)
# [03/19 14:05:59] ppgan INFO: Found /root/.cache/ppgan/GPEN-512.pdparams
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-dec7693047f2> in <module>
#       4
#       5 wav2lip_predictor = Wav2LipPredictor(face_det_batch_size = 2,wav2lip_batch_size = 16,face_enhancement = True)
# ----> 6 wav2lip_predictor.run("test.png", 'output.wav', 'res.mp4')
#
# /usr/local/lib/python3.9/dist-packages/ppgan/apps/wav2lip_predictor.py in run(self, face, audio_seq, outfile)
#     174
#     175         if not os.path.isfile(face):
# --> 176             raise ValueError(
#     177                 '--face argument must be a valid path to video/image file')
#     178
#
# ValueError: --face argument must be a valid path to video/image file

# %%
from paddlespeech.cli.asr.infer import ASRExecutor
from paddlespeech.cli.tts.infer import TTSExecutor
from paddlenlp import Taskflow
from ppgan.apps.wav2lip_predictor import Wav2LipPredictor
from ppgan.apps.first_order_predictor import FirstOrderPredictor
from ppdiffusers import StableDiffusionPipeline
# Out:
# /usr/local/lib/python3.9/dist-packages/librosa/core/constantq.py:1059: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.complex,

# %%
# 可选模型权重
# CompVis/stable-diffusion-v1-4
# runwayml/stable-diffusion-v1-5
# stabilityai/stable-diffusion-2-base （原始策略 512x512）
# stabilityai/stable-diffusion-2 （v-objective 768x768）
# Linaqruf/anything-v3.0
# ......


# from paddlenlp import Taskflow
# text_to_image = Taskflow("text_to_image")

# # https://github.com/JiehangXie/PaddleBoBo/blob/0.1/PaddleTools/GAN.py
sd = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
asr = ASRExecutor()
tts = TTSExecutor()
dialogue = Taskflow("dialogue")
wav2lip_predictor = Wav2LipPredictor(face_det_batch_size = 2,wav2lip_batch_size = 16,face_enhancement = True)

import base64,os
import librosa
import soundfile as sf

def resample_rate(path,new_sample_rate = 16000):
    signal, sr = librosa.load(path, sr=None)
    wavfile = path.split('/')[-1]
    wavfile = wavfile.split('.')[0]
    file_name = wavfile + '_new.wav'
    new_signal = librosa.resample(signal, sr, new_sample_rate) # 
    #librosa.output.write_wav(file_name, new_signal , new_sample_rate) 
    sf.write(file_name, new_signal, new_sample_rate, subtype='PCM_24')
    print(f'{file_name} has download.')
    return file_name

def text2img(text):
  prompt = "a portrait of "+text+".passport photo， intricate. lifelike. soft light. sony a 7 r iv 5 5 mm. cinematic post - processing "
  image = sd(prompt, 
        guidance_scale=7.5,
        num_inference_steps=20,
        height=416, width=416).images[0]
  return image


def audio2text(input_file):
  input_file=resample_rate(input_file,new_sample_rate = 16000)
  result = asr(audio_file=input_file)
  print('audio2text')
  return result

def text2audio(text):
  out_file =tts(text)
  print('text2audio')
  return out_file

def reply(t):
  data = [t]
  result = dialogue(data)
  print('reply',result[0])
  return result[0]

def wav2lip(input_video,input_audio):
  out_file='video.mp4'
  wav2lip_predictor.run(input_video, input_audio, out_file)
  return out_file


def FOM(source_image,driving_video,output_path):
  output,filename = os.path.split(output_path)
  first_order_predictor = FirstOrderPredictor(output = output,filename = filename, 
                              face_enhancement = True, 
                              ratio = 0.4,
                              relative = True,
                              image_size=512,
                              adapt_scale = True)
  first_order_predictor.run(source_image, driving_video)
  return os.path.join(output,filename)

def write_wav(data, samplerate,wav_file):
  # data, samplerate = sf.read('existing_file.wav')
  sf.write(wav_file, data, samplerate)
  return wav_file



#判断人脸
import face_recognition

def check_face_image(image_path):
  image = face_recognition.load_image_file(image_path)
  face_locations = face_recognition.face_locations(image)
  print("I found {} face(s) in this photograph.".format(len(face_locations)))

  if len(face_locations)==1:
    # top, right, bottom, left = face_locations[0]
    # width=right-left
    # height=bottom-top
    # s=(width*height)/(image.width*image.height)
    # if s>0.4:
    return True
  return False


# from fastapi import FastAPI, APIRouter,Body
# from fastapi.middleware.cors import CORSMiddleware
# from fastapi.responses import HTMLResponse

# app = FastAPI()
# api_router = APIRouter()

# origins = ['*']

# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=origins,
#     allow_credentials=True,
#     allow_methods=["*"],
#     allow_headers=["*"],
# )
# Out:
# [2023-03-19 13:39:25,942] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/model_index.json
# [2023-03-19 13:39:25,946] [    INFO] - Found /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json
# [2023-03-19 13:39:25,949] [    INFO] - loading configuration file https://bj.bcebos.com/paddlenlp/models/community/runwayml/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json from cache at /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json
# [2023-03-19 13:39:25,950] [    INFO] - size should be a dictionary on of the following set of keys: ({'width', 'height'}, {'shortest_edge'}, {'longest_edge', 'shortest_edge'}), got 224. Converted to {'shortest_edge': 224}.
# [2023-03-19 13:39:25,951] [    INFO] - crop_size should be a dictionary on of the following set of keys: ({'width', 'height'}, {'shortest_edge'}, {'longest_edge', 'shortest_edge'}), got 224. Converted to {'height': 224, 'width': 224}.
# [2023-03-19 13:39:25,953] [    INFO] - Image processor CLIPFeatureExtractor {
#   "crop_size": {
#     "height": 224,
#     "width": 224
#   },
#   "do_center_crop": true,
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "feature_extractor_type": "CLIPFeatureExtractor",
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "CLIPFeatureExtractor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "shortest_edge": 224
#   }
# }
#
# [2023-03-19 13:39:25,956] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer/vocab.json
# [2023-03-19 13:39:25,957] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer/merges.txt
# [2023-03-19 13:39:25,958] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer/added_tokens.json
# [2023-03-19 13:39:25,961] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer/special_tokens_map.json
# [2023-03-19 13:39:25,962] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/tokenizer/tokenizer_config.json
# [2023-03-19 13:39:26,057] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/unet/model_state.pdparams
# [2023-03-19 13:39:26,058] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/unet/config.json
# [2023-03-19 13:39:33,675] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/vae/model_state.pdparams
# [2023-03-19 13:39:33,678] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/vae/config.json
# [2023-03-19 13:39:35,653] [    INFO] - Found /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/safety_checker/config.json
# [2023-03-19 13:39:35,656] [    INFO] - loading configuration file /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/safety_checker/config.json
# [2023-03-19 13:39:35,658] [    INFO] - Model config CLIPVisionConfig {
#   "architectures": [
#     "StableDiffusionSafetyChecker"
#   ],
#   "attention_dropout": 0.0,
#   "dropout": 0.0,
#   "hidden_act": "quick_gelu",
#   "hidden_size": 1024,
#   "image_size": 224,
#   "initializer_factor": 1.0,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "model_type": "clip_vision_model",
#   "num_attention_heads": 16,
#   "num_channels": 3,
#   "num_hidden_layers": 24,
#   "paddlenlp_version": null,
#   "patch_size": 14,
#   "projection_dim": 768,
#   "return_dict": true
# }
#
# [2023-03-19 13:39:36,892] [    INFO] - Found /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/safety_checker/model_state.pdparams
# [2023-03-19 13:39:40,811] [    INFO] - All model checkpoint weights were used when initializing StableDiffusionSafetyChecker.
#
# [2023-03-19 13:39:40,812] [    INFO] - All the weights of StableDiffusionSafetyChecker were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5/safety_checker.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use StableDiffusionSafetyChecker for predictions without further training.
# [2023-03-19 13:39:41,837] [    INFO] - Found /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/text_encoder/config.json
# [2023-03-19 13:39:41,840] [    INFO] - loading configuration file /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/text_encoder/config.json
# [2023-03-19 13:39:41,843] [    INFO] - Model config CLIPTextConfig {
#   "_name_or_path": "openai/clip-vit-large-patch14",
#   "architectures": [
#     "CLIPTextModel"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "dropout": 0.0,
#   "eos_token_id": 2,
#   "hidden_act": "quick_gelu",
#   "hidden_size": 768,
#   "initializer_factor": 1.0,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 77,
#   "model_type": "clip_text_model",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "paddlenlp_version": null,
#   "projection_dim": 512,
#   "return_dict": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.21.0.dev0",
#   "vocab_size": 49408
# }
#
# [2023-03-19 13:39:42,867] [    INFO] - Found /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/text_encoder/model_state.pdparams
# [2023-03-19 13:39:43,690] [    INFO] - All model checkpoint weights were used when initializing CLIPTextModel.
#
# [2023-03-19 13:39:43,691] [    INFO] - All the weights of CLIPTextModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5/text_encoder.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use CLIPTextModel for predictions without further training.
# [2023-03-19 13:39:43,695] [    INFO] - Already cached /root/.paddlenlp/models/runwayml/stable-diffusion-v1-5/scheduler/scheduler_config.json
# [2023-03-19 13:39:46,509] [    INFO] - Already cached /root/.paddlenlp/models/plato-mini/plato-mini-vocab.txt
# [2023-03-19 13:39:46,511] [    INFO] - Already cached /root/.paddlenlp/models/plato-mini/plato-mini-spm.model
# [2023-03-19 13:39:46,561] [    INFO] - tokenizer config file saved in /root/.paddlenlp/models/plato-mini/tokenizer_config.json
# [2023-03-19 13:39:46,562] [    INFO] - Special tokens file saved in /root/.paddlenlp/models/plato-mini/special_tokens_map.json
# [2023-03-19 13:39:46,566] [    INFO] - Model config UnifiedTransformerConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "mask_token_id": 30000,
#   "max_position_embeddings": 512,
#   "model_type": "unified_transformer",
#   "normalize_before": true,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 6,
#   "pad_token_id": 0,
#   "paddlenlp_version": null,
#   "role_type_size": null,
#   "type_vocab_size": 2,
#   "unk_token_id": 0,
#   "vocab_size": 30001
# }
#
# [2023-03-19 13:39:49,389] [    INFO] - All model checkpoint weights were used when initializing UnifiedTransformerLMHeadModel.
#
# [2023-03-19 13:39:49,390] [    INFO] - All the weights of UnifiedTransformerLMHeadModel were initialized from the model checkpoint at plato-mini.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UnifiedTransformerLMHeadModel for predictions without further training.
# [03/19 13:39:49] ppgan INFO: Found /root/.cache/ppgan/GPEN-512.pdparams

# %%
# !pip install gradio
import os
import gradio as gr

from google.colab import drive

# 挂载网盘
drive.mount('/content/drive/')  
# 切换路径
os.chdir('/content/drive/MyDrive/data')

def step_by_step(wav_file_input):
    wav_file=write_wav(wav_file_input[1],wav_file_input[0],'./wav_file.wav')
    text=audio2text(wav_file)
    q=reply(text)
    print(q)
    
    input_audio=text2audio(q)
    img=text2img('pretty girl face')
    portrait='portrait.png'
    img.save(portrait)

    if check_face_image(portrait)==False:
      return portrait

    portrait_video=FOM(portrait,'driving_video.mp4','./portrait_video.mp4')
    # portrait_video=portrait
    result=wav2lip(portrait_video,wav_file)
    # os.path.join(os.path.dirname(__file__),  "video.mp4")
    print(result)
    return result

input_audio=gr.Audio(label="录音",type="numpy",source='microphone')

iface = gr.Interface(fn=step_by_step, inputs=[input_audio], outputs=[gr.Video()],
  layout="vertical")

iface.launch(share=True,debug=True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gradio in /usr/local/lib/python3.9/dist-packages (3.22.1)
# Requirement already satisfied: orjson in /usr/local/lib/python3.9/dist-packages (from gradio) (3.8.7)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from gradio) (1.10.6)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio) (2.1.2)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.9/dist-packages (from gradio) (0.21.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from gradio) (2.27.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.9/dist-packages (from gradio) (0.0.6)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (2.2.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.9/dist-packages (from gradio) (0.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from gradio) (1.4.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from gradio) (6.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /usr/local/lib/python3.9/dist-packages (from gradio) (0.3.3)
# Requirement already satisfied: httpx in /usr/local/lib/python3.9/dist-packages (from gradio) (0.23.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from gradio) (1.22.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio) (2023.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from gradio) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio) (4.5.0)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (4.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from gradio) (8.4.0)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (10.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.9/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from gradio) (3.8.4)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.9/dist-packages (from gradio) (23.1.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/dist-packages (from gradio) (0.95.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (4.3.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.0->gradio) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.0->gradio) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.0->gradio) (3.10.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /usr/local/lib/python3.9/dist-packages (from fastapi->gradio) (0.26.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (4.39.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->gradio) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->gradio) (1.26.15)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->gradio) (3.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.9/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.15.0)
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://a4abe92188194d5e37.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://a4abe92188194d5e37.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# wav_file_new.wav has download.
# audio2text
# reply 我18了
# text2audio
#   0%|          | 0/20 [00:00<?, ?it/s]
# I found 1 face(s) in this photograph.
# [03/19 14:07:32] ppgan INFO: Found /root/.cache/ppgan/vox-cpk-512.pdparams
# [03/19 14:07:33] ppgan INFO: Found /root/.cache/ppgan/GPEN-512.pdparams
# [2023-03-19 14:07:34,944] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:07:34,944] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:07:34,947] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# [2023-03-19 14:07:34,947] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# 1 persons have been detected
# 100%|██████████| 169/169 [00:39<00:00,  4.28it/s]
# Reading video frames...
# Number of frames available for inference: 169
# Length of mel chunks: 48
# [2023-03-19 14:08:17,742] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:08:17,742] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:08:17,745] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/wav2lip_hq.pdparams
# [2023-03-19 14:08:17,745] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/wav2lip_hq.pdparams
# Model loaded
#   0%|          | 0/3 [00:00<?, ?it/s][2023-03-19 14:08:17,934] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:08:17,934] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:08:17,937] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# [2023-03-19 14:08:17,937] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#   4%|▍         | 1/24 [00:00<00:03,  6.11it/s]
#   8%|▊         | 2/24 [00:00<00:03,  6.46it/s]
#  12%|█▎        | 3/24 [00:00<00:03,  6.54it/s]
#  17%|█▋        | 4/24 [00:00<00:02,  6.82it/s]
#  21%|██        | 5/24 [00:00<00:02,  6.94it/s]
#  25%|██▌       | 6/24 [00:00<00:02,  7.03it/s]
#  29%|██▉       | 7/24 [00:01<00:02,  7.13it/s]
#  33%|███▎      | 8/24 [00:01<00:02,  7.30it/s]
#  38%|███▊      | 9/24 [00:01<00:02,  7.36it/s]
#  42%|████▏     | 10/24 [00:01<00:01,  7.60it/s]
#  46%|████▌     | 11/24 [00:01<00:01,  7.79it/s]
#  50%|█████     | 12/24 [00:01<00:01,  7.91it/s]
#  54%|█████▍    | 13/24 [00:01<00:01,  8.04it/s]
#  58%|█████▊    | 14/24 [00:01<00:01,  8.10it/s]
#  62%|██████▎   | 15/24 [00:02<00:01,  8.19it/s]
#  67%|██████▋   | 16/24 [00:02<00:00,  8.26it/s]
#  71%|███████   | 17/24 [00:02<00:00,  8.36it/s]
#  75%|███████▌  | 18/24 [00:02<00:00,  8.35it/s]
#  79%|███████▉  | 19/24 [00:02<00:00,  8.29it/s]
#  83%|████████▎ | 20/24 [00:02<00:00,  8.30it/s]
#  88%|████████▊ | 21/24 [00:02<00:00,  8.28it/s]
#  92%|█████████▏| 22/24 [00:02<00:00,  8.12it/s]
#  96%|█████████▌| 23/24 [00:02<00:00,  8.08it/s]
# 100%|██████████| 24/24 [00:03<00:00,  7.74it/s]
# 100%|██████████| 3/3 [00:09<00:00,  3.30s/it]
# video.mp4
# wav_file_new.wav has download.
# audio2text
# reply 我是女生,18岁岁,今年大二了
# text2audio
#   0%|          | 0/20 [00:00<?, ?it/s]
# I found 1 face(s) in this photograph.
# [03/19 14:12:05] ppgan INFO: Found /root/.cache/ppgan/vox-cpk-512.pdparams
# [03/19 14:12:05] ppgan INFO: Found /root/.cache/ppgan/GPEN-512.pdparams
# [2023-03-19 14:12:06,950] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:12:06,950] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:12:06,953] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# [2023-03-19 14:12:06,953] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# 1 persons have been detected
# 100%|██████████| 169/169 [00:39<00:00,  4.29it/s]
# Reading video frames...
# Number of frames available for inference: 169
# [2023-03-19 14:12:49,224] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:12:49,224] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:12:49,231] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/wav2lip_hq.pdparams
# [2023-03-19 14:12:49,231] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/wav2lip_hq.pdparams
# Length of mel chunks: 225
# Model loaded
#   0%|          | 0/15 [00:00<?, ?it/s][2023-03-19 14:12:49,429] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:12:49,429] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:12:49,433] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# [2023-03-19 14:12:49,433] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
#
#   0%|          | 0/85 [00:00<?, ?it/s]
#   1%|          | 1/85 [00:00<00:11,  7.51it/s]
#   2%|▏         | 2/85 [00:00<00:10,  7.78it/s]
#   4%|▎         | 3/85 [00:00<00:10,  8.11it/s]
#   5%|▍         | 4/85 [00:00<00:09,  8.39it/s]
#   6%|▌         | 5/85 [00:00<00:09,  8.59it/s]
#   7%|▋         | 6/85 [00:00<00:09,  8.73it/s]
#   8%|▊         | 7/85 [00:00<00:08,  8.98it/s]
#   9%|▉         | 8/85 [00:00<00:08,  9.06it/s]
#  11%|█         | 9/85 [00:01<00:08,  9.15it/s]
#  12%|█▏        | 10/85 [00:01<00:08,  9.19it/s]
#  13%|█▎        | 11/85 [00:01<00:08,  9.23it/s]
#  14%|█▍        | 12/85 [00:01<00:08,  8.90it/s]
#  15%|█▌        | 13/85 [00:01<00:08,  8.83it/s]
#  16%|█▋        | 14/85 [00:01<00:07,  8.91it/s]
#  18%|█▊        | 15/85 [00:01<00:07,  9.00it/s]
#  19%|█▉        | 16/85 [00:01<00:07,  9.14it/s]
#  20%|██        | 17/85 [00:01<00:07,  9.25it/s]
#  21%|██        | 18/85 [00:02<00:07,  9.27it/s]
#  22%|██▏       | 19/85 [00:02<00:07,  9.39it/s]
#  24%|██▎       | 20/85 [00:02<00:06,  9.51it/s]
#  25%|██▍       | 21/85 [00:02<00:06,  9.51it/s]
#  26%|██▌       | 22/85 [00:02<00:06,  9.47it/s]
#  27%|██▋       | 23/85 [00:02<00:06,  9.49it/s]
#  28%|██▊       | 24/85 [00:02<00:06,  9.51it/s]
#  29%|██▉       | 25/85 [00:02<00:06,  9.47it/s]
#  31%|███       | 26/85 [00:02<00:06,  9.49it/s]
#  32%|███▏      | 27/85 [00:02<00:06,  9.55it/s]
#  33%|███▎      | 28/85 [00:03<00:05,  9.57it/s]
#  34%|███▍      | 29/85 [00:03<00:05,  9.52it/s]
#  35%|███▌      | 30/85 [00:03<00:05,  9.41it/s]
#  36%|███▋      | 31/85 [00:03<00:05,  9.40it/s]
#  38%|███▊      | 32/85 [00:03<00:05,  9.43it/s]
#  39%|███▉      | 33/85 [00:03<00:05,  9.41it/s]
#  40%|████      | 34/85 [00:03<00:05,  9.43it/s]
#  41%|████      | 35/85 [00:03<00:05,  9.47it/s]
#  42%|████▏     | 36/85 [00:03<00:05,  9.56it/s]
#  44%|████▎     | 37/85 [00:04<00:04,  9.61it/s]
#  45%|████▍     | 38/85 [00:04<00:04,  9.54it/s]
#  46%|████▌     | 39/85 [00:04<00:04,  9.53it/s]
#  47%|████▋     | 40/85 [00:04<00:04,  9.49it/s]
#  48%|████▊     | 41/85 [00:04<00:04,  9.50it/s]
#  49%|████▉     | 42/85 [00:04<00:04,  9.48it/s]
#  51%|█████     | 43/85 [00:04<00:04,  9.37it/s]
#  52%|█████▏    | 44/85 [00:04<00:04,  9.40it/s]
#  53%|█████▎    | 45/85 [00:04<00:04,  9.43it/s]
#  54%|█████▍    | 46/85 [00:04<00:04,  9.43it/s]
#  55%|█████▌    | 47/85 [00:05<00:04,  9.47it/s]
#  56%|█████▋    | 48/85 [00:05<00:03,  9.44it/s]
#  58%|█████▊    | 49/85 [00:05<00:03,  9.42it/s]
#  59%|█████▉    | 50/85 [00:05<00:03,  9.42it/s]
#  60%|██████    | 51/85 [00:05<00:03,  9.46it/s]
#  61%|██████    | 52/85 [00:05<00:03,  9.28it/s]
#  62%|██████▏   | 53/85 [00:05<00:03,  9.19it/s]
#  64%|██████▎   | 54/85 [00:05<00:03,  9.20it/s]
#  65%|██████▍   | 55/85 [00:05<00:03,  9.26it/s]
#  66%|██████▌   | 56/85 [00:06<00:03,  9.27it/s]
#  67%|██████▋   | 57/85 [00:06<00:02,  9.35it/s]
#  68%|██████▊   | 58/85 [00:06<00:02,  9.32it/s]
#  69%|██████▉   | 59/85 [00:06<00:02,  9.09it/s]
#  71%|███████   | 60/85 [00:06<00:02,  9.10it/s]
#  72%|███████▏  | 61/85 [00:06<00:02,  8.96it/s]
#  73%|███████▎  | 62/85 [00:06<00:02,  9.08it/s]
#  74%|███████▍  | 63/85 [00:06<00:02,  9.14it/s]
#  75%|███████▌  | 64/85 [00:06<00:02,  9.02it/s]
#  76%|███████▋  | 65/85 [00:07<00:02,  8.99it/s]
#  78%|███████▊  | 66/85 [00:07<00:02,  9.05it/s]
#  79%|███████▉  | 67/85 [00:07<00:02,  8.73it/s]
#  80%|████████  | 68/85 [00:07<00:01,  8.86it/s]
#  81%|████████  | 69/85 [00:07<00:01,  8.99it/s]
#  82%|████████▏ | 70/85 [00:07<00:01,  9.01it/s]
#  84%|████████▎ | 71/85 [00:07<00:01,  9.00it/s]
#  85%|████████▍ | 72/85 [00:07<00:01,  8.93it/s]
#  86%|████████▌ | 73/85 [00:07<00:01,  8.96it/s]
#  87%|████████▋ | 74/85 [00:08<00:01,  8.88it/s]
#  88%|████████▊ | 75/85 [00:08<00:01,  8.81it/s]
#  89%|████████▉ | 76/85 [00:08<00:01,  8.92it/s]
#  91%|█████████ | 77/85 [00:08<00:00,  8.98it/s]
#  92%|█████████▏| 78/85 [00:08<00:00,  9.03it/s]
#  93%|█████████▎| 79/85 [00:08<00:00,  9.06it/s]
#  94%|█████████▍| 80/85 [00:08<00:00,  8.96it/s]
#  95%|█████████▌| 81/85 [00:08<00:00,  8.88it/s]
#  96%|█████████▋| 82/85 [00:08<00:00,  8.99it/s]
#  98%|█████████▊| 83/85 [00:09<00:00,  8.94it/s]
# 100%|██████████| 85/85 [00:09<00:00,  9.22it/s]
# 100%|██████████| 15/15 [00:39<00:00,  2.64s/it]
# video.mp4
# wav_file_new.wav has download.
# audio2text
# reply 你怎么了,是生病了吗?
# text2audio
#   0%|          | 0/20 [00:00<?, ?it/s]
# I found 1 face(s) in this photograph.
# [03/19 14:15:54] ppgan INFO: Found /root/.cache/ppgan/vox-cpk-512.pdparams
# [03/19 14:15:55] ppgan INFO: Found /root/.cache/ppgan/GPEN-512.pdparams
# [2023-03-19 14:15:56,294] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:15:56,294] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:15:56,297] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# [2023-03-19 14:15:56,297] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# 1 persons have been detected
# 100%|██████████| 169/169 [00:39<00:00,  4.24it/s]
# Reading video frames...
# Number of frames available for inference: 169
# [2023-03-19 14:16:39,029] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:16:39,029] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:16:39,031] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/wav2lip_hq.pdparams
# [2023-03-19 14:16:39,031] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/wav2lip_hq.pdparams
# Length of mel chunks: 105
# Model loaded
#   0%|          | 0/7 [00:00<?, ?it/s][2023-03-19 14:16:39,226] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:16:39,226] [    INFO] - PaddleAudio | unique_endpoints {''}
# [2023-03-19 14:16:39,230] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
# [2023-03-19 14:16:39,230] [    INFO] - PaddleAudio | Found /root/.cache/paddle/hapi/weights/s3fd_paddle.pdparams
#
#   0%|          | 0/53 [00:00<?, ?it/s]
#   2%|▏         | 1/53 [00:00<00:07,  7.00it/s]
#   4%|▍         | 2/53 [00:00<00:07,  6.93it/s]
#   6%|▌         | 3/53 [00:00<00:07,  7.10it/s]
#   8%|▊         | 4/53 [00:00<00:06,  7.10it/s]
#   9%|▉         | 5/53 [00:00<00:06,  7.35it/s]
#  11%|█▏        | 6/53 [00:00<00:06,  7.40it/s]
#  13%|█▎        | 7/53 [00:00<00:06,  7.30it/s]
#  15%|█▌        | 8/53 [00:01<00:06,  7.42it/s]
#  17%|█▋        | 9/53 [00:01<00:05,  7.52it/s]
#  19%|█▉        | 10/53 [00:01<00:05,  7.65it/s]
#  21%|██        | 11/53 [00:01<00:05,  7.59it/s]
#  23%|██▎       | 12/53 [00:01<00:05,  7.72it/s]
#  25%|██▍       | 13/53 [00:01<00:05,  7.75it/s]
#  26%|██▋       | 14/53 [00:01<00:05,  7.66it/s]
#  28%|██▊       | 15/53 [00:01<00:04,  7.76it/s]
#  30%|███       | 16/53 [00:02<00:04,  7.90it/s]
#  32%|███▏      | 17/53 [00:02<00:04,  7.96it/s]
#  34%|███▍      | 18/53 [00:02<00:04,  7.37it/s]
#  36%|███▌      | 19/53 [00:02<00:04,  6.98it/s]
#  38%|███▊      | 20/53 [00:02<00:04,  7.03it/s]
#  40%|███▉      | 21/53 [00:02<00:04,  7.35it/s]
#  42%|████▏     | 22/53 [00:02<00:04,  7.63it/s]
#  43%|████▎     | 23/53 [00:03<00:03,  7.82it/s]
#  45%|████▌     | 24/53 [00:03<00:03,  7.99it/s]
#  47%|████▋     | 25/53 [00:03<00:03,  8.17it/s]
#  49%|████▉     | 26/53 [00:03<00:03,  8.23it/s]
#  51%|█████     | 27/53 [00:03<00:03,  8.23it/s]
#  53%|█████▎    | 28/53 [00:03<00:03,  8.28it/s]
#  55%|█████▍    | 29/53 [00:03<00:02,  8.32it/s]
#  57%|█████▋    | 30/53 [00:03<00:02,  8.31it/s]
#  58%|█████▊    | 31/53 [00:04<00:02,  8.32it/s]
#  60%|██████    | 32/53 [00:04<00:02,  8.32it/s]
#  62%|██████▏   | 33/53 [00:04<00:02,  8.34it/s]
#  64%|██████▍   | 34/53 [00:04<00:02,  8.30it/s]
#  66%|██████▌   | 35/53 [00:04<00:02,  8.23it/s]
#  68%|██████▊   | 36/53 [00:04<00:02,  8.28it/s]
#  70%|██████▉   | 37/53 [00:04<00:01,  8.40it/s]
#  72%|███████▏  | 38/53 [00:04<00:01,  8.50it/s]
#  74%|███████▎  | 39/53 [00:04<00:01,  8.42it/s]
#  75%|███████▌  | 40/53 [00:05<00:01,  8.50it/s]
#  77%|███████▋  | 41/53 [00:05<00:01,  8.55it/s]
#  79%|███████▉  | 42/53 [00:05<00:01,  8.49it/s]
#  81%|████████  | 43/53 [00:05<00:01,  8.54it/s]
#  83%|████████▎ | 44/53 [00:05<00:01,  8.49it/s]
#  85%|████████▍ | 45/53 [00:05<00:00,  8.46it/s]
#  87%|████████▋ | 46/53 [00:05<00:00,  8.40it/s]
#  89%|████████▊ | 47/53 [00:05<00:00,  8.37it/s]
#  91%|█████████ | 48/53 [00:06<00:00,  8.43it/s]
#  92%|█████████▏| 49/53 [00:06<00:00,  8.40it/s]
#  94%|█████████▍| 50/53 [00:06<00:00,  8.44it/s]
#  96%|█████████▌| 51/53 [00:06<00:00,  8.52it/s]
# 100%|██████████| 53/53 [00:06<00:00,  8.07it/s]
# 100%|██████████| 7/7 [00:20<00:00,  2.98s/it]
# video.mp4

# %% [markdown]
# # 新段落
